# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### min f(x)=100(x1^2 - x2)^2 + (x1 - 1)^2

# %% [markdown]
# ### 当x1 = x2 = 1时，其有最小值0

# %%
def ofun(x):
    return 100*(x[0,0]**2 - x[0,1])**2 + (x[0,0]-1)**2
def gfun(x):
    result = np.zeros([2, 1])
    result[0, 0] = 400*x[0,0]*(x[0,0]**2 - x[0,1]) + 2*(x[0,0]-1)
    result[1, 0] = -200*(x[0,0]**2 - x[0,1])
    return result

# %% [markdown]
# ### 自编程DFP算法，利用矩阵np.mat，未利用海森矩阵的信息

# %%
def dfp_algorithm(ofun, gfun, x0): 
    n = np.shape(x0)[1]  
    H0 = np.mat(np.eye(n))  
    maxk = 1e8
    rho = 0.05
    sigma = 0.4
    epsilon = 1e-5      
    k = 0 
    while k < maxk:    
        
        #1.停止条件
        g0 = np.mat(gfun(x0))    #1*2矩阵
        if np.linalg.norm(g0) < epsilon:
            break   
        dk = -1 * np.dot(H0, g0)             
        
        
        #2.用Armijo搜索步长
        m = 0
        mk = 0
        while(m < 50):
            if ofun((x0.T + rho**m*dk).T) < ofun(x0) + sigma*rho**m*np.dot(g0.T, dk)[0,0]:
                mk = m
                break
            m = m+1
        xk = (x0.T + rho**mk*dk).T
        print ("第"+str(k)+"次的迭代结果为："+str(xk))
       
    
        3.#DFP校正矩阵
        sk = xk -np.mat(x0)
        yk = np.mat(gfun(xk)).T - g0.T
        if np.dot(sk, yk.T)[0,0] > 0:
            Hy = np.dot(H0, yk.T)
            sy = np.dot(sk, yk.T)[0,0]
            yHy = np.dot(np.dot(yk,H0), yk.T)[0,0]
            H0 = H0 - np.dot(np.dot(Hy, yk), H0) / yHy + np.dot(sk.T, sk) / sy
        k = k+1
        x0 = xk
    return x0, ofun(x0), k

# %%
dfp_algorithm(ofun, gfun, np.mat([3,1]))
# Out:
# 第0次的迭代结果为：[[1.7995 1.2   ]]
# 第1次的迭代结果为：[[1.86795485 1.67092556]]
# 第2次的迭代结果为：[[2.098796   4.01650939]]
# 第3次的迭代结果为：[[2.1269962 4.4904661]]
# 第4次的迭代结果为：[[2.12774819 4.52629357]]
# 第5次的迭代结果为：[[2.1262009  4.52047071]]
# 第6次的迭代结果为：[[2.07945267 4.34374191]]
# 第7次的迭代结果为：[[2.05746451 4.25967564]]
# 第8次的迭代结果为：[[2.00722243 4.06667256]]
# 第9次的迭代结果为：[[1.95541993 3.86745031]]
# 第10次的迭代结果为：[[1.85534918 3.48322768]]
# 第11次的迭代结果为：[[1.63188282 2.62645719]]
# 第12次的迭代结果为：[[1.63766762 2.64863231]]
# 第13次的迭代结果为：[[1.66788981 2.76483265]]
# 第14次的迭代结果为：[[1.67306593 2.78504904]]
# 第15次的迭代结果为：[[1.6757562  2.79589471]]
# 第16次的迭代结果为：[[1.67835313 2.80676921]]
# 第17次的迭代结果为：[[1.68000171 2.81416315]]
# 第18次的迭代结果为：[[1.68133585 2.8208051 ]]
# 第19次的迭代结果为：[[1.68190387 2.82457272]]
# 第20次的迭代结果为：[[1.68197973 2.826969  ]]
# 第21次的迭代结果为：[[1.68146723 2.8270905 ]]
# 第22次的迭代结果为：[[1.68029766 2.82528691]]
# 第23次的迭代结果为：[[1.6787043  2.82177618]]
# 第24次的迭代结果为：[[1.67627074 2.81574261]]
# 第25次的迭代结果为：[[1.67354022 2.80846083]]
# ...

# %%
import numpy as np

#函数表达式
fun = lambda x:100*(x[0]**2 - x[1]**2)**2 +(x[0] - 1)**2

#梯度向量
gfun = lambda x:np.array([400*x[0]*(x[0]**2 - x[1]) + 2*(x[0] - 1),-200*(x[0]**2 - x[1])])

#Hessian矩阵
hess = lambda x:np.array([[1200*x[0]**2 - 400*x[1] + 2,-400*x[0]],[-400*x[0],200]])

def dfp(fun,gfun,hess,x0):
    #功能：用DFP算法求解无约束问题：min fun(x)
    #输入：x0式初始点，fun,gfun，hess分别是目标函数和梯度,Hessian矩阵格式
    #输出：x,val分别是近似最优点，最优解，k是迭代次数
    maxk = 1e5
    rho = 0.05
    sigma = 0.4
    epsilon = 1e-5 #迭代停止条件
    k = 0
    n = np.shape(x0)[0]
    #将Hessian矩阵初始化为单位矩阵
    Hk = np.linalg.inv(hess(x0))

    while k < maxk:
        gk = gfun(x0)
        if np.linalg.norm(gk) < epsilon:
            break
        dk = -1.0*np.dot(Hk,gk)
#         print dk

        m = 0;
        mk = 0
        while m < 20:#用Armijo搜索步长
            if fun(x0 + rho**m*dk) < fun(x0) + sigma*rho**m*np.dot(gk,dk):
                mk = m
                break
            m += 1
        #print mk
        #DFP校正
        x = x0 + rho**mk*dk
        print ("第"+str(k)+"次的迭代结果为："+str(x))
        sk = x - x0
        yk = gfun(x) - gk

        if np.dot(sk,yk) > 0:
            Hy = np.dot(Hk,yk)
            sy = np.dot(sk,yk) #向量的点积
            yHy = np.dot(np.dot(yk,Hk),yk) #yHy是标量
            Hk = Hk - 1.0*Hy.reshape((n,1))*Hy/yHy + 1.0*sk.reshape((n,1))*sk/sy

        k += 1
        x0 = x
    return x0,fun(x0),k

# %%
x0 ,fun0 ,k = dfp(fun,gfun,hess,np.array([3,1]))
print(x0,fun0,k)
# Out:
# 第0次的迭代结果为：[2.99993754 1.39962523]
# 第1次的迭代结果为：[2.99987508 1.77925048]
# 第2次的迭代结果为：[2.99980966 2.13985797]
# 第3次的迭代结果为：[2.99974115 2.48239693]
# 第4次的迭代结果为：[2.99966942 2.80776908]
# 第5次的迭代结果为：[2.99966566 2.82322218]
# 第6次的迭代结果为：[2.99966169 2.8386353 ]
# 第7次的迭代结果为：[2.99965767 2.85400949]
# 第8次的迭代结果为：[2.99965362 2.86934506]
# 第9次的迭代结果为：[2.99964956 2.88464215]
# 第10次的迭代结果为：[2.9996455  2.89990088]
# 第11次的迭代结果为：[2.99964142 2.91512134]
# 第12次的迭代结果为：[2.99963733 2.93030362]
# 第13次的迭代结果为：[2.99963733 2.93030362]
# 第14次的迭代结果为：[2.97059987 8.63965154]
# 第15次的迭代结果为：[2.96914895 8.81582717]
# 第16次的迭代结果为：[2.96791804 8.80868693]
# 第17次的迭代结果为：[2.27537417 4.79112091]
# 第18次的迭代结果为：[2.94009018 8.64729436]
# 第19次的迭代结果为：[2.91404959 8.49625949]
# 第20次的迭代结果为：[2.73083259 7.43358262]
# 第21次的迭代结果为：[2.55756639 6.42873344]
# 第22次的迭代结果为：[2.70803895 7.30147017]
# 第23次的迭代结果为：[2.69704134 7.2377679 ]
# 第24次的迭代结果为：[2.68582408 7.17288063]
# 第25次的迭代结果为：[2.68559564 7.17164489]
# 第26次的迭代结果为：[2.52114704 6.28212521]
# ...
